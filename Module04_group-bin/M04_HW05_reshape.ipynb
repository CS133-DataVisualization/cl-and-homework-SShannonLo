# %% [markdown]
# ## Where Do People Drink The Most Beer, Wine And Spirits?
#
# <img src="https://s1.qwant.com/thumbr/0x0/3/f/a2d61eb9aa851a55e62456389bde7986e358da62a08b5c5ac98aaa851447dc/alcoholconsumption.gif?u=http%3A%2F%2F4.bp.blogspot.com%2F-0u5Sk_omAEE%2FTV3XZtyPQ1I%2FAAAAAAAAArc%2FyVlSiUp6aTU%2Fs1600%2Falcoholconsumption.gif&q=0&b=1&p=0&a=1">
#
# The dataset for this analysis is from this post in [FiveThirtyEight](https://fivethirtyeight.com/features/dear-mona-followup-where-do-people-drink-the-most-beer-wine-and-spirits/)
#
# Data: https://raw.githubusercontent.com/fivethirtyeight/data/master/alcohol-consumption/drinks.csv

# %%
import pandas as pd

alc = pd.read_csv("https://raw.githubusercontent.com/fivethirtyeight/data/master/alcohol-consumption/drinks.csv")
alc.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol
# 0                           0.0
# 1                           4.9
# 2                           0.7
# 3                          12.4
# 4                           5.9

# %% [markdown]
# ## Problem 1
# Convert the following data into tidy format with the headers `country`, `drink` and `servings`. Drop the column `total_litres_of_pure_alcohol`

# %%
alc_adjusted = alc.drop(columns=['total_litres_of_pure_alcohol'])

tidy_alc = alc_adjusted.melt(
    id_vars="country",
    var_name="drink",
    value_name="servings"
)

tidy_alc
# Out:
#          country          drink  servings
# 0    Afghanistan  beer_servings         0
# 1        Albania  beer_servings        89
# 2        Algeria  beer_servings        25
# 3        Andorra  beer_servings       245
# 4         Angola  beer_servings       217
# ..           ...            ...       ...
# 574    Venezuela  wine_servings         3
# 575      Vietnam  wine_servings         1
# 576        Yemen  wine_servings         0
# 577       Zambia  wine_servings         4
# 578     Zimbabwe  wine_servings         4
#
# [579 rows x 3 columns]

# %% [markdown]
# ## Problem 2
# Remove `"_servings"` from the data in the tidy dataframe in Problem 1. Who drinks the most beer, wine and spirits? Create three categorical plots of your choice to illustrate the top 10 countries that drink the most wine, beer or spirits.

# %%
tidy_alc['drink'] = tidy_alc['drink'].str.replace('_servings', '')
tidy_alc
# Out:
#          country drink  servings
# 0    Afghanistan  beer         0
# 1        Albania  beer        89
# 2        Algeria  beer        25
# 3        Andorra  beer       245
# 4         Angola  beer       217
# ..           ...   ...       ...
# 574    Venezuela  wine         3
# 575      Vietnam  wine         1
# 576        Yemen  wine         0
# 577       Zambia  wine         4
# 578     Zimbabwe  wine         4
#
# [579 rows x 3 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

top_beer = tidy_alc[tidy_alc['drink'] == 'beer'].nlargest(10, 'servings')
top_wine = tidy_alc[tidy_alc['drink'] == 'wine'].nlargest(10, 'servings')
top_spirits = tidy_alc[tidy_alc['drink'] == 'spirit'].nlargest(10, 'servings')


# Beer chart using horizonal tbar chart
plt.figure()
sns.barplot(data=top_beer, x='servings', y='country', color='steelblue')
plt.title('Top 10 Beer Drinking Countries')
plt.show()

# %%
# Wine chart using a vertical bar chart
plt.figure()
sns.stripplot(data=top_wine, x='servings', y='country', color='firebrick', size=10)
plt.title('Top 10 Wine Drinking Countries')
plt.show()

# %%
# Spirits chart using a scatter plot
plt.figure()
sns.violinplot(data=top_spirits, x='servings', y='country', color='goldenrod')
plt.title('Top 10 Spirit Drinking Countries')
plt.show()

# %% [markdown]
# ## Problem 3
# Create a wide dataframe using `pivot_table` with the tidy dataframe from Problem 2

# %%
pd.pivot_table(tidy_alc, values='servings',
                    index=['drink'],
                    columns='country',
                    aggfunc='min'
               )
# Out:
# country  Afghanistan  Albania  Algeria  Andorra  Angola  Antigua & Barbuda  \
# drink
# beer               0       89       25      245     217                102
# spirit             0      132        0      138      57                128
# wine               0       54       14      312      45                 45
#
# country  Argentina  Armenia  Australia  Austria  ...  United Arab Emirates  \
# drink                                            ...
# beer           193       21        261      279  ...                    16
# spirit          25      179         72       75  ...                   135
# wine           221       11        212      191  ...                     5
#
# country  United Kingdom  Uruguay  Uzbekistan  Vanuatu  Venezuela  Vietnam  \
# drink
# beer                219      115          25       21        333      111
# spirit              126       35         101       18        100        2
# wine                195      220           8       11          3        1
#
# country  Yemen  Zambia  Zimbabwe
# drink
# beer         6      32        64
# spirit       0      19        18
# wine         0       4         4
#
# [3 rows x 193 columns]
